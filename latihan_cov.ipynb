# %%
import json
from urllib import request

url = "https://data.covid19.go.id/public/api/prov.json"


response = request.urlopen(url)

data = json.loads(response.read())
i=0
for covid in data['list_data']:
  i=i+1
  print(f"{i,covid['key']}:")
  print(f"  ❗️Positif: {covid['jumlah_kasus']}")
  print(f"  😷Dirawat: {covid['jumlah_dirawat']}")
  print(f"  💊Sembuh: {covid['jumlah_sembuh']}")
  print(f"  🛌Meninggal: {covid['jumlah_meninggal']}")
# Out:
# (1, 'DKI JAKARTA'):
#   ❗️Positif: 419629
#   😷Dirawat: 7076
#   💊Sembuh: 405575
#   🛌Meninggal: 6978
# (2, 'JAWA BARAT'):
#   ❗️Positif: 298665
#   😷Dirawat: 29477
#   💊Sembuh: 265186
#   🛌Meninggal: 4002
# (3, 'JAWA TENGAH'):
#   ❗️Positif: 190623
#   😷Dirawat: 6758
#   💊Sembuh: 175080
#   🛌Meninggal: 8785
# (4, 'JAWA TIMUR'):
#   ❗️Positif: 151450
#   😷Dirawat: 1844
#   💊Sembuh: 138561
#   🛌Meninggal: 11045
# (5, 'KALIMANTAN TIMUR'):
#   ❗️Positif: 70138
#   😷Dirawat: 1063
#   💊Sembuh: 67395
#   🛌Meninggal: 1680
# (6, 'SULAWESI SELATAN'):
#   ❗️Positif: 61734
#   😷Dirawat: 278
#   💊Sembuh: 60520
#   🛌Meninggal: 936
# (7, 'RIAU'):
#   ❗️Positif: 51990
#   😷Dirawat: 4446
#   💊Sembuh: 46199
#   🛌Meninggal: 1345
# (8, 'BANTEN'):
#   ❗️Positif: 48481
#   😷Dirawat: 1670
#   💊Sembuh: 45578
#   🛌Meninggal: 1233
# (9, 'BALI'):
#   ❗️Positif: 46364
#   😷Dirawat: 1452
#   💊Sembuh: 43591
#   🛌Meninggal: 1321
# (10, 'DAERAH ISTIMEWA YOGYAKARTA'):
#   ❗️Positif: 42142
#   😷Dirawat: 2369
# ...

# %%
covin=data['list_data']
# for x in covin:
#   # if(x['key']=='DKI JAKARTA')
#   print(x['key'])
print(covin[2])
# Out:
# {'key': 'JAWA TENGAH', 'doc_count': 10.929935867480484, 'jumlah_kasus': 190623, 'jumlah_sembuh': 175080, 'jumlah_meninggal': 8785, 'jumlah_dirawat': 6758, 'jenis_kelamin': [{'key': 'LAKI-LAKI', 'doc_count': 78063}, {'key': 'PEREMPUAN', 'doc_count': 92791}], 'kelompok_umur': [{'key': '0-5', 'doc_count': 5411, 'usia': {'value': 5.0}}, {'key': '6-18', 'doc_count': 19212, 'usia': {'value': 18.0}}, {'key': '19-30', 'doc_count': 43473, 'usia': {'value': 30.0}}, {'key': '31-45', 'doc_count': 50476, 'usia': {'value': 45.0}}, {'key': '46-59', 'doc_count': 45691, 'usia': {'value': 59.0}}, {'key': '≥ 60', 'doc_count': 26106, 'usia': {'value': 2216.0}}], 'lokasi': {'lon': 110.20111493755839, 'lat': -7.259097176704969}, 'penambahan': {'positif': 673, 'sembuh': 905, 'meninggal': 44}}

# %%
import requests as r
import json

uri=r.get('https://data.covid19.go.id/public/api/prov.json')
prov=uri.json()
case=prov['list_data']
print(prov['list_data'])
i=0
for x in prov['list_data']:
  print(prov['list_data'][i]['key'])
  i=i+1
# print(prov['list_data'][0]['jumlah_kasus'])
print(case[0]['key'])
# Out:
# [{'key': 'DKI JAKARTA', 'doc_count': 24.060675039921563, 'jumlah_kasus': 419629, 'jumlah_sembuh': 405575, 'jumlah_meninggal': 6978, 'jumlah_dirawat': 7076, 'jenis_kelamin': [{'key': 'LAKI-LAKI', 'doc_count': 207335}, {'key': 'PEREMPUAN', 'doc_count': 208365}], 'kelompok_umur': [{'key': '0-5', 'doc_count': 12998, 'usia': {'value': 5.0}}, {'key': '6-18', 'doc_count': 36095, 'usia': {'value': 18.0}}, {'key': '19-30', 'doc_count': 106896, 'usia': {'value': 30.0}}, {'key': '31-45', 'doc_count': 123405, 'usia': {'value': 45.0}}, {'key': '46-59', 'doc_count': 87696, 'usia': {'value': 59.0}}, {'key': '≥ 60', 'doc_count': 45374, 'usia': {'value': 2003.0}}], 'lokasi': {'lon': 106.83611829006928, 'lat': -6.204698991169558}, 'penambahan': {'positif': 421, 'sembuh': 0, 'meninggal': 25}}, {'key': 'JAWA BARAT', 'doc_count': 17.124844829118516, 'jumlah_kasus': 298665, 'jumlah_sembuh': 265186, 'jumlah_meninggal': 4002, 'jumlah_dirawat': 29477, 'jenis_kelamin': [{'key': 'LAKI-LAKI', 'doc_count': 14077
# ...

# %%
import json
gg = '''{"last_date": "2021-05-17", "current_data": 100.0, "missing_data": 0.0, "tanpa_provinsi": 0, "list_data": [{"key": "DKI JAKARTA", "doc_count": 24.060675039921563, "jumlah_kasus": 419629, "jumlah_sembuh": 405575, "jumlah_meninggal": 6978, "jumlah_dirawat": 7076, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 207335}, {"key": "PEREMPUAN", "doc_count": 208365}], "kelompok_umur": [{"key": "0-5", "doc_count": 12998, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 36095, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 106896, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 123405, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 87696, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 45374, "usia": {"value": 2003.0}}], "lokasi": {"lon": 106.83611829006928, "lat": -6.204698991169558}, "penambahan": {"positif": 421, "sembuh": 0, "meninggal": 25}}, {"key": "JAWA BARAT", "doc_count": 17.124844829118516, "jumlah_kasus": 298665, "jumlah_sembuh": 265186, "jumlah_meninggal": 4002, "jumlah_dirawat": 29477, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 140778}, {"key": "PEREMPUAN", "doc_count": 150944}], "kelompok_umur": [{"key": "0-5", "doc_count": 9926, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 34512, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 71234, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 81962, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 64443, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 28588, "usia": {"value": 9783561644.0}}], "lokasi": {"lon": 107.60370834146391, "lat": -6.920432082789247}, "penambahan": {"positif": 1361, "sembuh": 1143, "meninggal": 26}}, {"key": "JAWA TENGAH", "doc_count": 10.929935867480484, "jumlah_kasus": 190623, "jumlah_sembuh": 175080, "jumlah_meninggal": 8785, "jumlah_dirawat": 6758, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 78063}, {"key": "PEREMPUAN", "doc_count": 92791}], "kelompok_umur": [{"key": "0-5", "doc_count": 5411, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 19212, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 43473, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 50476, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 45691, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 26106, "usia": {"value": 2216.0}}], "lokasi": {"lon": 110.20111493755839, "lat": -7.259097176704969}, "penambahan": {"positif": 673, "sembuh": 905, "meninggal": 44}}, {"key": "JAWA TIMUR", "doc_count": 8.683835566169451, "jumlah_kasus": 151450, "jumlah_sembuh": 138561, "jumlah_meninggal": 11045, "jumlah_dirawat": 1844, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count":
"usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 938, "usia": {"value": 1925.0}}], "lokasi": {"lat": 3.916346, "lon": 108.261746}, "penambahan": {"positif": 106, "sembuh": 4, "meninggal": 1}}, {"key": "SULAWESI TENGAH", "doc_count": 0.7281348818407781, "jumlah_kasus": 12699, "jumlah_sembuh": 11892, "jumlah_meninggal": 351, "jumlah_dirawat": 456, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 5658}, {"key": "PEREMPUAN", "doc_count": 7033}], "kelompok_umur": [{"key": "0-5", "doc_count": 268, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 843, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 3680, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 4042, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 2369, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 1127, "usia": {"value": 1947.0}}], "lokasi": {"lon": 121.20109267528304, "lat": -1.0041366797829747}, "penambahan": {"positif": 14, "sembuh": 79, "meninggal": 2}}, {"key": "ACEH", "doc_count": 0.7075505505878575, "jumlah_kasus": 12340, "jumlah_sembuh": 10375, "jumlah_meninggal": 499, "jumlah_dirawat": 1466, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 6070}, {"key": "PEREMPUAN", "doc_count": 6250}], "kelompok_umur": [{"key": "0-5", "doc_count": 243, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 676, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2802, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 4123, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 2948, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 1528, "usia": {"value": 2020.0}}], "lokasi": {"lon": 96.9105217406655, "lat": 4.225614627700759}, "penambahan": {"positif": 91, "sembuh": 22, "meninggal": 5}}, {"key": "KALIMANTAN UTARA", "doc_count": 0.6822645057897014, "jumlah_kasus": 11899, "jumlah_sembuh": 11276, "jumlah_meninggal": 188, "jumlah_dirawat": 435, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 6610}, {"key": "PEREMPUAN", "doc_count": 5245}], "kelompok_umur": [{"key": "0-5", "doc_count": 238, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 1226, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 3439, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 3941, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 2198, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 792, "usia": {"value": 1955.0}}], "lokasi": {"lon": 116.2188791390853, "lat": 2.8910126208140725}, "penambahan": {"positif": 4, "sembuh": 14, "meninggal": 0}}, {"key": "NUSA TENGGARA BARAT", "doc_count": 0.6228050308334934, "jumlah_kasus": 10862, "jumlah_sembuh": 7985, "jumlah_meninggal": 414, "jumlah_dirawat": 2463, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 5364}, {"key": "PEREMPUAN", "doc_count": 5490}], "kelompok_umur": [{"key": "0-5", "doc_count": 273, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 698, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2956, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 3414, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 2222, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 1272, "usia": {"value": 1824.0}}], "lokasi": {"lon": 117.50862565333749, "lat": -8.606998865706263}, "penambahan": {"positif": 12, "sembuh": 0, "meninggal": 0}}, {"key": "SULAWESI TENGGARA", "doc_count": 0.6003858845385296, "jumlah_kasus": 10471, "jumlah_sembuh": 9998, "jumlah_meninggal": 215, "jumlah_dirawat": 258, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 5109}, {"key": "PEREMPUAN", "doc_count": 5296}], "kelompok_umur": [{"key": "0-5", "doc_count": 181, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 679, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 3305, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 3588, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1847, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 755, "usia": {"value": 829.0}}], "lokasi": {"lon": 122.07031100195121, "lat": -4.124688793498832}, "penambahan": {"positif": 1, "sembuh": 14, "meninggal": 0}}, {"key": "KALIMANTAN BARAT", "doc_count": 0.5362246960370862, "jumlah_kasus": 9352, "jumlah_sembuh": 8547, "jumlah_meninggal": 70, "jumlah_dirawat": 735, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 4651}, {"key": "PEREMPUAN", "doc_count": 4676}], "kelompok_umur": [{"key": "0-5", "doc_count": 229, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 995, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2386, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 2656, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 2036, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 938, "usia": {"value": 949.0}}], "lokasi": {"lon": 111.12117763730221, "lat": -0.08647457175645347}, "penambahan": {"positif": 72, "sembuh": 161, "meninggal": 3}}, {"key": "PAPUA BARAT", "doc_count": 0.5249864539045723, "jumlah_kasus": 9156, "jumlah_sembuh": 8834, "jumlah_meninggal": 155, "jumlah_dirawat": 167, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 4800}, {"key": "PEREMPUAN", "doc_count": 4340}], "kelompok_umur": [{"key": "0-5", "doc_count": 290, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 890, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2831, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 2999, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1466, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 637, "usia": {"value": 2109.0}}], "lokasi": {"lon": 132.9762624116817, "lat": -2.045160182312363}, "penambahan": {"positif": 1, "sembuh": 18, "meninggal": 1}}, {"key": "JAMBI", "doc_count": 0.49838163579494793, "jumlah_kasus": 8692, "jumlah_sembuh": 7033, "jumlah_meninggal": 141, "jumlah_dirawat": 1518, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 3254}, {"key": "PEREMPUAN", "doc_count": 3762}], "kelompok_umur": [{"key": "0-5", "doc_count": 249, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 1199, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2205, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 2439, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1783, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 755, "usia": {"value": 2016.0}}], "lokasi": {"lon": 102.72364042732815, "lat": -1.6976976604117253}, "penambahan": {"positif": 21, "sembuh": 48, "meninggal": 0}}, {"key": "MALUKU", "doc_count": 0.43897949880880366, "jumlah_kasus": 7656, "jumlah_sembuh": 7223, "jumlah_meninggal": 120, "jumlah_dirawat": 313, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 3593}, {"key": "PEREMPUAN", "doc_count": 3958}], "kelompok_umur": [{"key": "0-5", "doc_count": 94, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 605, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 2110, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 2687, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1459, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 461, "usia": {"value": 44432.0}}], "lokasi": {"lat": -3.192572, "lon": 129.576792}, "penambahan": {"positif": 20, "sembuh": 5, "meninggal": 0}}, {"key": "BENGKULU", "doc_count": 0.4269958630654599, "jumlah_kasus": 7447, "jumlah_sembuh": 6571, "jumlah_meninggal": 175, "jumlah_dirawat": 701, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 3362}, {"key": "PEREMPUAN", "doc_count": 3993}], "kelompok_umur": [{"key": "0-5", "doc_count": 163, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 713, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 1706, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 2322, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1658, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 859, "usia": {"value": 1821.0}}], "lokasi": {"lon": 102.33842134883429, "lat": -3.5335836266267204}, "penambahan": {"positif": 4, "sembuh": 17, "meninggal": 0}}, {"key": "SULAWESI BARAT", "doc_count": 0.315014807530769, "jumlah_kasus": 5494, "jumlah_sembuh": 5318, "jumlah_meninggal": 120, "jumlah_dirawat": 56, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 2445}, {"key": "PEREMPUAN", "doc_count": 3047}], "kelompok_umur": [{"key": "0-5", "doc_count": 91, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 824, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 1550, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 1780, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 816, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 415, "usia": {"value": 2020.0}}], "lokasi": {"lon": 119.34501936431505, "lat": -2.4617460526098855}, "penambahan": {"positif": 3, "sembuh": 3, "meninggal": 0}}, {"key": "GORONTALO", "doc_count": 0.3118038812071936, "jumlah_kasus": 5438, "jumlah_sembuh": 5127, "jumlah_meninggal": 170, "jumlah_dirawat": 141, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 2642}, {"key": "PEREMPUAN", "doc_count": 2792}], "kelompok_umur": [{"key": "0-5", "doc_count": 92, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 277, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 1725, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 1839, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 1057, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 404, "usia": {"value": 2021.0}}], "lokasi": {"lon": 122.37605812253207, "lat": 0.687002604326393}, "penambahan": {"positif": 2, "sembuh": 8, "meninggal": 0}}, {"key": "MALUKU UTARA", "doc_count": 0.2550966288140501, "jumlah_kasus": 4449, "jumlah_sembuh": 4232, "jumlah_meninggal": 120, "jumlah_dirawat": 97, "jenis_kelamin": [{"key": "LAKI-LAKI", "doc_count": 2367}, {"key": "PEREMPUAN", "doc_count": 1851}], "kelompok_umur": [{"key": "0-5", "doc_count": 72, "usia": {"value": 5.0}}, {"key": "6-18", "doc_count": 252, "usia": {"value": 18.0}}, {"key": "19-30", "doc_count": 1301, "usia": {"value": 30.0}}, {"key": "31-45", "doc_count": 1536, "usia": {"value": 45.0}}, {"key": "46-59", "doc_count": 758, "usia": {"value": 59.0}}, {"key": "\u2265 60", "doc_count": 274, "usia": {"value": 2020.0}}], "lokasi": {"lon": 127.53910724599248, "lat": 0.21203694908578316}, "penambahan": {"positif": 0, "sembuh": 8, "meninggal": 0}}]}'''

rr=json.loads(gg)
print(type(rr))
print(type(rr['list_data']))
# print(rr['list_data'][5])
# for pr in rr['list_data']:
#   print(pr['key'],pr['jumlah_kasus']) 
for pr in rr['list_data']:
  # del pr['doc_count']
  print(pr)
# Out:
# <class 'dict'>
# <class 'list'>
# {'key': 'DKI JAKARTA', 'doc_count': 24.060675039921563, 'jumlah_kasus': 419629, 'jumlah_sembuh': 405575, 'jumlah_meninggal': 6978, 'jumlah_dirawat': 7076, 'jenis_kelamin': [{'key': 'LAKI-LAKI', 'doc_count': 207335}, {'key': 'PEREMPUAN', 'doc_count': 208365}], 'kelompok_umur': [{'key': '0-5', 'doc_count': 12998, 'usia': {'value': 5.0}}, {'key': '6-18', 'doc_count': 36095, 'usia': {'value': 18.0}}, {'key': '19-30', 'doc_count': 106896, 'usia': {'value': 30.0}}, {'key': '31-45', 'doc_count': 123405, 'usia': {'value': 45.0}}, {'key': '46-59', 'doc_count': 87696, 'usia': {'value': 59.0}}, {'key': '≥ 60', 'doc_count': 45374, 'usia': {'value': 2003.0}}], 'lokasi': {'lon': 106.83611829006928, 'lat': -6.204698991169558}, 'penambahan': {'positif': 421, 'sembuh': 0, 'meninggal': 25}}
# ...

# %%
for pr in rr['list_data']:
  print(pr['key'],pr['jumlah_kasus'])
# Out:
# DKI JAKARTA 419629
# JAWA BARAT 298665
# JAWA TENGAH 190623
# JAWA TIMUR 151450
# KALIMANTAN TIMUR 70138
# SULAWESI SELATAN 61734
# RIAU 51990
# BANTEN 48481
# BALI 46364
# DAERAH ISTIMEWA YOGYAKARTA 42142
# SUMATERA BARAT 40379
# KALIMANTAN SELATAN 33898
# SUMATERA UTARA 30723
# SUMATERA SELATAN 22420
# KALIMANTAN TENGAH 21309
# PAPUA 20433
# LAMPUNG 17069
# KEPULAUAN BANGKA BELITUNG 15757
# SULAWESI UTARA 15724
# NUSA TENGGARA TIMUR 15635
# KEPULAUAN RIAU 13527
# SULAWESI TENGAH 12699
# ACEH 12340
# KALIMANTAN UTARA 11899
# NUSA TENGGARA BARAT 10862
# SULAWESI TENGGARA 10471
# KALIMANTAN BARAT 9352
# PAPUA BARAT 9156
# JAMBI 8692
# MALUKU 7656
# BENGKULU 7447
# SULAWESI BARAT 5494
# GORONTALO 5438
# MALUKU UTARA 4449
